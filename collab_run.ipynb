# %%
# !git clone https://github.com/anshulsubramanian/video_relight.git
# Out:
# Cloning into 'video_relight'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 13 (delta 0), reused 13 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (13/13), 17.14 KiB | 337.00 KiB/s, done.

# %%
# %cd video_relight
# Out:
# /content/video_relight

# %%
# !pip install -r requirements.txt
# !python download_models.py
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.0/277.0 MB 4.8 MB/s eta 0:00:00
# ...
#   [########################################] 100.0%  15.0/15.0 MB
#   [done] rvm_mobilenetv3_fp32.onnx (15.0 MB)
# ...
#   [########################################] 100.0%  99.2/99.2 MB
#   [done] depth_anything_v2_vits.pth (99.2 MB)
#
# All models ready. Total checkpoint size: 114.2 MB

# %%
# !python run.py --input input/video1.mp4 --output relit.mp4 --light-dir 0.5 0.8 0.3 --light-intensity 3.0 --roughness 0.4
# Out:
# [run.py] Using device: cuda
# [run.py] Input: 1920×1080 @ 50.00 FPS, 500 frames
# [Pipeline] Loading RVM MobileNetV3 …
# 2026-05-30 19:21:40.397360454 [W:onnxruntime:, transformer_memcpy.cc:111 ApplyImpl] 1 Memcpy nodes are added to the graph torch-jit-export for CUDAExecutionProvider. It might have negative impact on performance (including unable to run CUDA graph). Set session_options.log_severity_level=1 to see the detail logs before this message.
# [Pipeline] Loading Depth-Anything-V2-Small …
# Loading weights: 100% 287/287 [00:00<00:00, 1023.27it/s, Materializing param=neck.reassemble_stage.layers.3.resize.weight]
# [Pipeline] Ready on cuda.
# [run.py] Processing …
#   frame     1/500  (  0.2%)  0.3 FPS
#   frame     8/500  (  1.6%)  1.4 FPS
#   frame    15/500  (  3.0%)  1.9 FPS
#   frame    22/500  (  4.4%)  2.2 FPS
#   frame    28/500  (  5.6%)  2.4 FPS
#   frame    34/500  (  6.8%)  3.2 FPS
#   frame    41/500  (  8.2%)  3.2 FPS
#   frame    48/500  (  9.6%)  3.2 FPS
# ...
